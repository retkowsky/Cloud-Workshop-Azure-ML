# %% [markdown]
# # Cloud Workshop Microsoft
# ## 1. Préparation de données avec Azure ML service
#
# Exemple données ville de Chicago<br>

# %% [markdown]
# ## 0. Paramétrage

# %%
#!pip install --upgrade azureml-dataprep

# %%
from IPython.display import display
from os import path
from tempfile import mkdtemp

import pandas as pd
import azureml.dataprep as dprep

# Données
file_crime_dirty  = 'data/crime-dirty.csv'
file_crime_spring = 'data/crime-spring.csv'
file_crime_winter = 'data/crime-winter.csv'
file_aldermen     = 'data/chicago-aldermen-2015.csv'

# Seed
RAND_SEED = 7251

# %% [markdown]
# <a id="Read"></a>

# %% [markdown]
# ## 1. Lecture des données
#
# Azure ML Data Prep supports many different file reading formats (i.e. CSV, Excel, Parquet) and the ability to infer column types automatically. To see how powerful the `auto_read_file` capability is, let's take a peek at the `dirty-crime.csv`:

# %%
dprep.read_csv(path=file_crime_dirty).head(10)
# Out:
#                               File updated 11/2/2018          Column2
# 0                                                                None
# 1                                                                None
# 2                                                                None
# 3  ID|Case Number|Date|Block|IUCR|Primary Type|De...             None
# 4  10140490|HY329907|07/05/2015 11:50:00 PM|050XX...   -87.800174996)
# 5  10139776|HY329265|07/05/2015 11:30:00 PM|011XX...    -87.65955018)
# 6  10140270|HY329253|07/05/2015 11:20:00 PM|121XX...             None
# 7  10139885|HY329308|07/05/2015 11:19:00 PM|051XX...   -87.754883404)
# 8  10140379|HY329556|07/05/2015 11:00:00 PM|012XX...   -87.657008701)
# 9  10140868|HY330421|07/05/2015 10:54:00 PM|118XX...   -87.644545209)

# %% [markdown]
# A common occurrence in many datasets is to have a column of values with commas; in our case, the last column represents location in the form of longitude-latitude pair. The default CSV reader interprets this comma as a delimiter and thus splits the data into two columns. Furthermore, it incorrectly reads in the header as the column name. Normally, we would need to `skip` the header and specify the delimiter as `|`, but our `auto_read_file` eliminates that work:

# %%
crime_dirty = dprep.auto_read_file(path=file_crime_dirty)

# %%
crime_dirty.head(10)
# Out:
#            ID Case Number                    Date                     Block  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM       050XX N NEWLAND AVE
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM         011XX W MORSE AVE
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM         121XX S FRONT AVE
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM       051XX W DIVISION ST
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM           012XX W LAKE ST
# 5  10140868.0    HY330421  07/05/2015 10:54:00 PM         118XX S PEORIA ST
# 6  10139762.0    HY329232  07/05/2015 10:42:00 PM           026XX W 37TH PL
# 7  10139722.0    HY329228  07/05/2015 10:30:00 PM  016XX S CENTRAL PARK AVE
# 8  10139774.0    HY329209  07/05/2015 10:15:00 PM       048XX N ASHLAND AVE
# 9  10139697.0    HY329177  07/05/2015 10:10:00 PM      058XX S ARTESIAN AVE
#
#      IUCR         Primary Type                   Description  \
# 0   820.0                THEFT                $500 AND UNDER
# 1   460.0              BATTERY                        SIMPLE
# 2   486.0              BATTERY       DOMESTIC BATTERY SIMPLE
# 3   610.0             BURGLARY                FORCIBLE ENTRY
# 4   930.0  MOTOR VEHICLE THEFT    THEFT/RECOVERY: AUTOMOBILE
# 5  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
# 6  1020.0                ARSON                       BY FIRE
# 7  1811.0            NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 8  1310.0      CRIMINAL DAMAGE                   TO PROPERTY
# 9  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
#
#      Location Description  Arrest  Domestic              ...                \
# 0                  STREET   False     False              ...
# 1                  STREET   False      True              ...
# 2                  STREET   False      True              ...
# 3      SMALL RETAIL STORE   False     False              ...
# 4                  STREET   False     False              ...
# 5  VEHICLE NON-COMMERCIAL   False     False              ...
# 6         VACANT LOT/LAND   False     False              ...
# 7                   ALLEY    True     False              ...
# 8               APARTMENT   False     False              ...
# 9                   ALLEY   False     False              ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0  41.0            10.0        06     1129230.0    1933315.0  2015.0
# 1  49.0             1.0       08B     1167370.0    1946271.0  2015.0
# 2   9.0            53.0       08B           NaN          NaN  2015.0
# 3  37.0            25.0        05     1141721.0    1907465.0  2015.0
# 4  27.0            28.0        07     1168413.0    1901632.0  2015.0
# 5  34.0            53.0        14     1172409.0    1826485.0  2015.0
# 6  12.0            58.0        09     1159436.0    1879658.0  2015.0
# 7  24.0            29.0        18     1152687.0    1891389.0  2015.0
# 8  46.0             3.0        14     1164821.0    1932394.0  2015.0
# 9  16.0            63.0        14     1160997.0    1865851.0  2015.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  07/12/2015 12:42:46 PM  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  07/12/2015 12:42:46 PM  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2  07/12/2015 12:42:46 PM        NaN        NaN
# 3  07/12/2015 12:42:46 PM  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  07/12/2015 12:42:46 PM  41.885610 -87.657009  (41.885610142, -87.657008701)
# 5  07/12/2015 12:42:46 PM  41.679311 -87.644545    (41.6793109, -87.644545209)
# 6  07/12/2015 12:42:46 PM  41.825501 -87.690578  (41.825500607, -87.690578042)
# 7  07/12/2015 12:42:46 PM  41.857828 -87.715029  (41.857827814, -87.715028789)
# 8  07/12/2015 12:42:46 PM  41.970100 -87.669324  (41.970099796, -87.669324377)
# 9  07/12/2015 12:42:46 PM  41.787580 -87.685233  (41.787580282, -87.685233078)
#
# [10 rows x 22 columns]

# %% [markdown]
# __Advanced features:__ if you'd like to specify the file type and adjust how you want to read files in, you can see the list of our specialized file readers and how to use them [here](../../how-to-guides/data-ingestion.ipynb).

# %% [markdown]
# <a id="Profile"></a>

# %% [markdown]
# ## 2. Audit des données
# Let's understand what our data looks like. Azure ML Data Prep facilitates this process by offering data profiles that help us glimpse into column types and column summary statistics. Notice that our auto file reader automatically guessed the column type:

# %%
crime_dirty.get_profile()
# Out:
# ColumnProfile:
#     column_name: ID
#     type: FieldType.DECIMAL
#
#     min: 10139697.0
#     max: 10140868.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 10139697.0
#            1%: 10139709.5
#            5%: 10139697.0
#           25%: 10139762.0
#           50%: 10139830.5
#           75%: 10140379.0
#           95%: 10140868.0
#           99%: 10140868.0
#         99.9%: 10140868.0
#
#     mean: 10140062.299999999
#     std: 409.80565854762824
#     variance: 167940.67777765525
#     skewness: 0.6883524570707924
#     kurtosis: -1.1536428984684086
#
# ColumnProfile:
#     column_name: Case Number
#     type: FieldType.STRING
#
#     min: HY329177
#     max: HY330421
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: Date
#     type: FieldType.STRING
#
#     min: 07/05/2015 10:10:00 PM
#     max: 07/05/2015 11:50:00 PM
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: Block
#     type: FieldType.STRING
#
#     min: 011XX W MORSE AVE
#     max: 121XX S FRONT AVE
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: IUCR
#     type: FieldType.DECIMAL
#
#     min: 460.0
#     max: 1811.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 460.0
#            1%: 473.0
#            5%: 460.0
#           25%: 610.0
#           50%: 975.0
#           75%: 1320.0
#           95%: 1811.0
#           99%: 1811.0
#         99.9%: 1811.0
#
#     mean: 1008.6999999999999
#     std: 435.0555647781608
#     variance: 189273.34444444446
#     skewness: 0.273880231989922
#     kurtosis: -1.2324333429507028
#
# ColumnProfile:
#     column_name: Primary Type
#     type: FieldType.STRING
#
#     min: ARSON
#     max: THEFT
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: Description
#     type: FieldType.STRING
#
#     min: $500 AND UNDER
#     max: TO VEHICLE
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: Location Description
#     type: FieldType.STRING
#
#     min: ALLEY
#     max: VEHICLE NON-COMMERCIAL
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: Arrest
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: Domestic
#     type: FieldType.BOOLEAN
#
#     min: False
#     max: True
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: Beat
#     type: FieldType.DECIMAL
#
#     min: 524.0
#     max: 2431.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 524.0
#            1%: 528.0
#            5%: 524.0
#           25%: 824.0
#           50%: 1118.0
#           75%: 1613.0
#           95%: 2431.0
#           99%: 2431.0
#         99.9%: 2431.0
#
#     mean: 1263.3999999999999
#     std: 633.1475516988297
#     variance: 400875.8222222222
#     skewness: 0.4606773427916479
#     kurtosis: -1.2148110554360347
#
# ColumnProfile:
#     column_name: District
#     type: FieldType.DECIMAL
#
#     min: 5.0
#     max: 24.0
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 5.0
#            1%: 6.2
#            5%: 5.0
#           25%: 8.75
#           50%: 12.0
#           75%: 17.0
#           95%: 24.0
#           99%: 24.0
#         99.9%: 24.0
#
#     mean: 13.222222222222221
#     std: 6.098724821177329
#     variance: 37.19444444444444
#     skewness: 0.3828128522782998
#     kurtosis: -1.2800261778487807
#
# ColumnProfile:
#     column_name: Ward
#     type: FieldType.DECIMAL
#
#     min: 9.0
#     max: 49.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 9.0
#            1%: 10.5
#            5%: 9.0
#           25%: 16.0
#           50%: 30.5
#           75%: 41.0
#           95%: 49.0
#           99%: 49.0
#         99.9%: 49.0
#
#     mean: 29.5
#     std: 14.167647024902275
#     variance: 200.72222222222226
#     skewness: -0.09410071523495527
#     kurtosis: -1.648918863969479
#
# ColumnProfile:
#     column_name: Community Area
#     type: FieldType.DECIMAL
#
#     min: 1.0
#     max: 63.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1.0
#            1%: 2.0
#            5%: 1.0
#           25%: 10.0
#           50%: 28.5
#           75%: 53.0
#           95%: 63.0
#           99%: 63.0
#         99.9%: 63.0
#
#     mean: 32.3
#     std: 23.281132083966863
#     variance: 542.0111111111112
#     skewness: -0.02982541942615151
#     kurtosis: -1.7612546753590468
#
# ColumnProfile:
#     column_name: FBI Code
#     type: FieldType.STRING
#
#     min: 05
#     max: 18
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: X Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1129230.0
#     max: 1172409.0
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1129230.0
#            1%: 1134226.4
#            5%: 1129230.0
#           25%: 1149945.5
#           50%: 1160997.0
#           75%: 1167630.75
#           95%: 1172409.0
#           99%: 1172409.0
#         99.9%: 1172409.0
#
#     mean: 1157453.7777777778
#     std: 14052.038898125935
#     variance: 197459797.19444433
#     skewness: -0.8167695241975886
#     kurtosis: -0.7955776867289264
#
# ColumnProfile:
#     column_name: Y Coordinate
#     type: FieldType.DECIMAL
#
#     min: 1826485.0
#     max: 1946271.0
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 1826485.0
#            1%: 1842231.4
#            5%: 1826485.0
#           25%: 1876206.25
#           50%: 1901632.0
#           75%: 1932624.25
#           95%: 1946271.0
#           99%: 1946271.0
#         99.9%: 1946271.0
#
#     mean: 1898273.3333333333
#     std: 37733.23942825477
#     variance: 1423797357.7500005
#     skewness: -0.4481360090688111
#     kurtosis: -1.028783137057662
#
# ColumnProfile:
#     column_name: Year
#     type: FieldType.DECIMAL
#
#     min: 2015.0
#     max: 2015.0
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 2015.0
#            1%: 2015.0
#            5%: 2015.0
#           25%: 2015.0
#           50%: 2015.0
#           75%: 2015.0
#           95%: 2015.0
#           99%: 2015.0
#         99.9%: 2015.0
#
#     mean: 2015.0
#     std: 0.0
#     variance: 0.0
#     skewness: nan
#     kurtosis: nan
#
# ColumnProfile:
#     column_name: Updated On
#     type: FieldType.STRING
#
#     min: 07/12/2015 12:42:46 PM
#     max: 07/12/2015 12:42:46 PM
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 0.0
#
#
# ColumnProfile:
#     column_name: Latitude
#     type: FieldType.DECIMAL
#
#     min: 41.6793109
#     max: 42.008124017
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: 41.6793109
#            1%: 41.722618652799994
#            5%: 41.6793109
#           25%: 41.81602052575
#           50%: 41.885610142
#           75%: 41.9709022135
#           95%: 42.008124017
#           99%: 42.008124017
#         99.9%: 42.008124017
#
#     mean: 41.87661278344444
#     std: 0.10364520556300645
#     variance: 0.010742328636197864
#     skewness: -0.4504133511718018
#     kurtosis: -1.027551479452864
#
# ColumnProfile:
#     column_name: Longitude
#     type: FieldType.DECIMAL
#
#     min: -87.800174996
#     max: -87.644545209
#     count: 10.0
#     missing_count: 1.0
#     not_missing_count: 9.0
#     percent_missing: 0.1
#     error_count: 0.0
#     empty_count: 0.0
#
#
#     Quantiles:
#          0.1%: -87.800174996
#            1%: -87.7820583592
#            5%: -87.800174996
#           25%: -87.72499244275
#           50%: -87.685233078
#           75%: -87.65891481025
#           95%: -87.644545209
#           99%: -87.644545209
#         99.9%: -87.644545209
#
#     mean: -87.6973696417778
#     std: 0.05125709218559426
#     variance: 0.0026272894993225084
#     skewness: -0.8175649306454071
#     kurtosis: -0.8129192475091398
#
# ColumnProfile:
#     column_name: Location
#     type: FieldType.STRING
#
#     min:
#     max: (42.008124017, -87.65955018)
#     count: 10.0
#     missing_count: 0.0
#     not_missing_count: 10.0
#     percent_missing: 0.0
#     error_count: 0.0
#     empty_count: 1.0

# %% [markdown]
# <a id="Append"></a>

# %% [markdown]
# ## 3. Concaténation des données
# What if your data is split across multiple files? We support the ability to append multiple datasets column-wise and row-wise. Here, we demonstrate how you can coalesce datasets row-wise:

# %%
crime_winter = dprep.auto_read_file(path=file_crime_winter)
crime_spring = dprep.auto_read_file(path=file_crime_spring)

# %%
crime = (crime_dirty.append_rows(dataflows=[crime_winter, crime_spring]))

# %%
crime.head(10)
# Out:
#            ID Case Number                    Date                     Block  \
# 0  10140490.0    HY329907  07/05/2015 11:50:00 PM       050XX N NEWLAND AVE
# 1  10139776.0    HY329265  07/05/2015 11:30:00 PM         011XX W MORSE AVE
# 2  10140270.0    HY329253  07/05/2015 11:20:00 PM         121XX S FRONT AVE
# 3  10139885.0    HY329308  07/05/2015 11:19:00 PM       051XX W DIVISION ST
# 4  10140379.0    HY329556  07/05/2015 11:00:00 PM           012XX W LAKE ST
# 5  10140868.0    HY330421  07/05/2015 10:54:00 PM         118XX S PEORIA ST
# 6  10139762.0    HY329232  07/05/2015 10:42:00 PM           026XX W 37TH PL
# 7  10139722.0    HY329228  07/05/2015 10:30:00 PM  016XX S CENTRAL PARK AVE
# 8  10139774.0    HY329209  07/05/2015 10:15:00 PM       048XX N ASHLAND AVE
# 9  10139697.0    HY329177  07/05/2015 10:10:00 PM      058XX S ARTESIAN AVE
#
#      IUCR         Primary Type                   Description  \
# 0   820.0                THEFT                $500 AND UNDER
# 1   460.0              BATTERY                        SIMPLE
# 2   486.0              BATTERY       DOMESTIC BATTERY SIMPLE
# 3   610.0             BURGLARY                FORCIBLE ENTRY
# 4   930.0  MOTOR VEHICLE THEFT    THEFT/RECOVERY: AUTOMOBILE
# 5  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
# 6  1020.0                ARSON                       BY FIRE
# 7  1811.0            NARCOTICS  POSS: CANNABIS 30GMS OR LESS
# 8  1310.0      CRIMINAL DAMAGE                   TO PROPERTY
# 9  1320.0      CRIMINAL DAMAGE                    TO VEHICLE
#
#      Location Description  Arrest  Domestic              ...                \
# 0                  STREET   False     False              ...
# 1                  STREET   False      True              ...
# 2                  STREET   False      True              ...
# 3      SMALL RETAIL STORE   False     False              ...
# 4                  STREET   False     False              ...
# 5  VEHICLE NON-COMMERCIAL   False     False              ...
# 6         VACANT LOT/LAND   False     False              ...
# 7                   ALLEY    True     False              ...
# 8               APARTMENT   False     False              ...
# 9                   ALLEY   False     False              ...
#
#    Ward  Community Area  FBI Code  X Coordinate Y Coordinate    Year  \
# 0  41.0            10.0        06     1129230.0    1933315.0  2015.0
# 1  49.0             1.0       08B     1167370.0    1946271.0  2015.0
# 2   9.0            53.0       08B           NaN          NaN  2015.0
# 3  37.0            25.0        05     1141721.0    1907465.0  2015.0
# 4  27.0            28.0        07     1168413.0    1901632.0  2015.0
# 5  34.0            53.0        14     1172409.0    1826485.0  2015.0
# 6  12.0            58.0        09     1159436.0    1879658.0  2015.0
# 7  24.0            29.0        18     1152687.0    1891389.0  2015.0
# 8  46.0             3.0        14     1164821.0    1932394.0  2015.0
# 9  16.0            63.0        14     1160997.0    1865851.0  2015.0
#
#                Updated On   Latitude  Longitude                       Location
# 0  07/12/2015 12:42:46 PM  41.973309 -87.800175  (41.973309466, -87.800174996)
# 1  07/12/2015 12:42:46 PM  42.008124 -87.659550   (42.008124017, -87.65955018)
# 2  07/12/2015 12:42:46 PM        NaN        NaN
# 3  07/12/2015 12:42:46 PM  41.902152 -87.754883  (41.902152027, -87.754883404)
# 4  07/12/2015 12:42:46 PM  41.885610 -87.657009  (41.885610142, -87.657008701)
# 5  07/12/2015 12:42:46 PM  41.679311 -87.644545    (41.6793109, -87.644545209)
# 6  07/12/2015 12:42:46 PM  41.825501 -87.690578  (41.825500607, -87.690578042)
# 7  07/12/2015 12:42:46 PM  41.857828 -87.715029  (41.857827814, -87.715028789)
# 8  07/12/2015 12:42:46 PM  41.970100 -87.669324  (41.970099796, -87.669324377)
# 9  07/12/2015 12:42:46 PM  41.787580 -87.685233  (41.787580282, -87.685233078)
#
# [10 rows x 22 columns]

# %% [markdown]
# ### Echantillon

# %%
crime.take_sample(probability=0.25, seed=RAND_SEED).head(5)
# Out:
#            ID Case Number                        Date                 Block  \
# 0  10140270.0    HY329253      07/05/2015 11:20:00 PM     121XX S FRONT AVE
# 1  10374287.0    HZ110730             1/10/2016 11:50  043XX W ARMITAGE AVE
# 2  10375178.0    HZ110832             1/10/2016 14:20    057XX S KEDZIE AVE
# 3  10535059.0    HZ278872  2016-04-15T04:30:00.000000  004XX S KILBOURN AVE
#
#      IUCR   Primary Type              Description Location Description  \
# 0   486.0        BATTERY  DOMESTIC BATTERY SIMPLE               STREET
# 1  5002.0  OTHER OFFENSE    OTHER VEHICLE OFFENSE               STREET
# 2   460.0        BATTERY                   SIMPLE           RESTAURANT
# 3   810.0          THEFT                OVER $500            RESIDENCE
#
#    Arrest  Domestic              ...                Ward  Community Area  \
# 0   False      True              ...                 9.0            53.0
# 1   False      True              ...                30.0            20.0
# 2   False     False              ...                14.0            63.0
# 3   False     False              ...                24.0            26.0
#
#    FBI Code  X Coordinate Y Coordinate    Year          Updated On   Latitude  \
# 0       08B           NaN          NaN  2015.0 2015-07-12 12:42:46        NaN
# 1        26     1146917.0    1912931.0  2016.0 2016-06-07 15:55:00  41.917054
# 2       08B     1156029.0    1866379.0  2016.0 2016-02-04 15:44:00  41.789131
# 3         6           NaN          NaN  2016.0 2016-05-25 15:59:00        NaN
#
#    Longitude                       Location
# 0        NaN
# 1 -87.735658  (41.917053561, -87.735657637)
# 2 -87.703435   (41.78913051, -87.703434602)
# 3        NaN
#
# [4 rows x 22 columns]

# %% [markdown]
# __Advanced features:__ you can learn how to append column-wise and how to deal with appending data with different schemas [here](../../how-to-guides/append-columns-and-rows.ipynb).

# %% [markdown]
# <a id="Data-science-transforms"></a>

# %% [markdown]
# ## 4. Autres fonctions disponibles
#
# Azure ML Data Prep supports almost all common data science transforms found in other industry-standard data science libraries. Here, we'll explore the ability to `summarize`, `join`, `filter`, and `replace`.
#
# __Advanced features:__
# * We also provide "smart" transforms not found in pandas that use machine learning to [derive new columns](../../how-to-guides/derive-column-by-example.ipynb), [split columns](../../how-to-guides/split-column-by-example.ipynb), and [fuzzy grouping](../../how-to-guides/fuzzy-group.ipynb).
# * Finally, we also help featurize your dataset to prepare it for machine learning; learn more about our featurizers like [one-hot encoder](../../how-to-guides/one-hot-encoder.ipynb), [label encoder](../../how-to-guides/label-encoder.ipynb), [min-max scaler](../../how-to-guides/min-max-scaler.ipynb), and [random (train-test) split](../../how-to-guides/random-split.ipynb).
# * Our complete list of example Notebooks for transforms can be found in our [How-to Guides](../../how-to-guides).

# %% [markdown]
# ## 5. Agrégation
#
# Let's see which wards had the most crimes in our sample dataset:

# %%
crime_summary = (crime
    .summarize(
        summary_columns=[
            dprep.SummaryColumnsValue(
                column_id='ID', 
                summary_column_name='TOTAL_par_zonegeo', 
                summary_function=dprep.SummaryFunction.COUNT
            )
        ],
        group_by_columns=['Ward']
    )
)

(crime_summary
     .sort(sort_order=[('TOTAL_par_zonegeo', True)])
     .head(5)
)
# Out:
#    Ward  TOTAL_par_zonegeo
# 0   9.0                  3
# 1  41.0                  2
# 2  16.0                  2
# 3  24.0                  2
# 4  14.0                  2

# %% [markdown]
# <a id="Join"></a>

# %% [markdown]
# ## 6. Jointure
#
# Let's annotate each observation with more information about the ward where the crime occurred. Let's do so by joining `crime` with a dataset which lists the current aldermen (juge) for each ward:

# %%
juge = dprep.auto_read_file(path=file_aldermen)

# %%
juge.head(5)
# Out:
#    Ward              Name Took Office Party
# 0   1.0  Proco Joe Moreno       2010*   Dem
# 1   2.0     Brian Hopkins        2015   Dem
# 2   3.0        Pat Dowell        2007   Dem
# 3   4.0       Sophia King       2016*   Dem
# 4   5.0   Leslie Hairston        1999   Dem

# %%
crime.join(
    left_dataflow=crime,
    right_dataflow=juge,
    join_key_pairs=[
        ('Ward', 'Ward')
    ]
).head(5)
# Out:
#          l_ID l_Case Number                      l_Date              l_Block  \
# 0  10140490.0      HY329907      07/05/2015 11:50:00 PM  050XX N NEWLAND AVE
# 1  10400131.0      HZ136171             1/10/2016 18:00  0000X W TERMINAL ST
# 2  10139776.0      HY329265      07/05/2015 11:30:00 PM    011XX W MORSE AVE
# 3  10140270.0      HY329253      07/05/2015 11:20:00 PM    121XX S FRONT AVE
# 4  10498554.0      HZ239907  2016-04-15T23:56:00.000000     007XX E 111TH ST
#
#    l_IUCR      l_Primary Type                        l_Description  \
# 0   820.0               THEFT                       $500 AND UNDER
# 1   810.0               THEFT                            OVER $500
# 2   460.0             BATTERY                               SIMPLE
# 3   486.0             BATTERY              DOMESTIC BATTERY SIMPLE
# 4  1153.0  DECEPTIVE PRACTICE  FINANCIAL IDENTITY THEFT OVER $ 300
#
#                         l_Location Description  l_Arrest  l_Domestic   ...     \
# 0                                       STREET     False       False   ...
# 1  AIRPORT BUILDING NON-TERMINAL - SECURE AREA     False       False   ...
# 2                                       STREET     False        True   ...
# 3                                       STREET     False        True   ...
# 4                                        OTHER     False       False   ...
#
#    l_Y Coordinate  l_Year        l_Updated On  l_Latitude l_Longitude  \
# 0       1933315.0  2015.0 2015-07-12 12:42:46   41.973309  -87.800175
# 1             NaN  2016.0 2016-02-02 15:58:00         NaN         NaN
# 2       1946271.0  2015.0 2015-07-12 12:42:46   42.008124  -87.659550
# 3             NaN  2015.0 2015-07-12 12:42:46         NaN         NaN
# 4       1831503.0  2016.0 2016-05-11 15:48:00   41.692834  -87.604319
#
#                       l_Location  r_Ward              r_Name r_Took Office  \
# 0  (41.973309466, -87.800174996)    41.0  Anthony Napolitano          2015
# 1                                   41.0  Anthony Napolitano          2015
# 2   (42.008124017, -87.65955018)    49.0           Joe Moore          1991
# 3                                    9.0       Anthony Beale          1999
# 4   (41.692833841, -87.60431945)     9.0       Anthony Beale          1999
#
#    r_Party
# 0      Rep
# 1      Rep
# 2      Dem
# 3      Dem
# 4      Dem
#
# [5 rows x 26 columns]

# %% [markdown]
# __Advanced features:__ [Learn more](../../how-to-guides/join.ipynb) about how you can do all variants of `join`, like inner-, left-, right-, anti-, and semi-joins.

# %% [markdown]
# <a id="Filter"></a>

# %% [markdown]
# ## 7. Filtres
#
# Let's look at theft crimes:

# %%
theft = crime.filter(crime['Primary Type'] == 'THEFT')

theft.head(5)
# Out:
#            ID Case Number                        Date                   Block  \
# 0  10140490.0    HY329907      07/05/2015 11:50:00 PM     050XX N NEWLAND AVE
# 1  10374720.0    HZ110836              1/10/2016 7:30      079XX S RHODES AVE
# 2  10400131.0    HZ136171             1/10/2016 18:00     0000X W TERMINAL ST
# 3  10516598.0    HZ258664  2016-04-15T17:00:00.000000  082XX S MARSHFIELD AVE
# 4  10534446.0    HZ277630  2016-04-15T10:00:00.000000      055XX N KEDZIE AVE
#
#     IUCR Primary Type     Description  \
# 0  820.0        THEFT  $500 AND UNDER
# 1  890.0        THEFT   FROM BUILDING
# 2  810.0        THEFT       OVER $500
# 3  890.0        THEFT   FROM BUILDING
# 4  890.0        THEFT   FROM BUILDING
#
#                           Location Description  Arrest  Domestic  \
# 0                                       STREET   False     False
# 1                                        OTHER   False     False
# 2  AIRPORT BUILDING NON-TERMINAL - SECURE AREA   False     False
# 3                                    RESIDENCE   False     False
# 4                     SCHOOL, PUBLIC, BUILDING   False     False
#
#                ...                Ward  Community Area  FBI Code  \
# 0              ...                41.0            10.0        06
# 1              ...                 6.0            44.0         6
# 2              ...                41.0            76.0         6
# 3              ...                21.0            71.0         6
# 4              ...                40.0            13.0         6
#
#    X Coordinate Y Coordinate    Year          Updated On   Latitude  \
# 0     1129230.0    1933315.0  2015.0 2015-07-12 12:42:46  41.973309
# 1     1181279.0    1852568.0  2016.0 2016-02-04 15:44:00  41.750687
# 2           NaN          NaN  2016.0 2016-02-02 15:58:00        NaN
# 3     1166776.0    1850053.0  2016.0 2016-05-12 15:48:00  41.744107
# 4           NaN          NaN  2016.0 2016-05-25 15:59:00        NaN
#
#    Longitude                       Location
# 0 -87.800175  (41.973309466, -87.800174996)
# 1 -87.611277   (41.75068679, -87.611276811)
# 2        NaN
# 3 -87.664494  (41.744106973, -87.664494285)
# 4        NaN
#
# [5 rows x 22 columns]

# %% [markdown]
# <a id="Replace"></a>

# %% [markdown]
# ## 8. Remplacement de données
#
# Notice that our `theft` dataset has empty strings in column `Location`. Let's replace those with a missing value:

# %%
theft_replaced = (theft
    .replace_na(
        columns=['Location'], 
        use_empty_string_as_na=True
    )
)

theft_replaced.head(5)
# Out:
#            ID Case Number                        Date                   Block  \
# 0  10140490.0    HY329907      07/05/2015 11:50:00 PM     050XX N NEWLAND AVE
# 1  10374720.0    HZ110836              1/10/2016 7:30      079XX S RHODES AVE
# 2  10400131.0    HZ136171             1/10/2016 18:00     0000X W TERMINAL ST
# 3  10516598.0    HZ258664  2016-04-15T17:00:00.000000  082XX S MARSHFIELD AVE
# 4  10534446.0    HZ277630  2016-04-15T10:00:00.000000      055XX N KEDZIE AVE
#
#     IUCR Primary Type     Description  \
# 0  820.0        THEFT  $500 AND UNDER
# 1  890.0        THEFT   FROM BUILDING
# 2  810.0        THEFT       OVER $500
# 3  890.0        THEFT   FROM BUILDING
# 4  890.0        THEFT   FROM BUILDING
#
#                           Location Description  Arrest  Domestic  \
# 0                                       STREET   False     False
# 1                                        OTHER   False     False
# 2  AIRPORT BUILDING NON-TERMINAL - SECURE AREA   False     False
# 3                                    RESIDENCE   False     False
# 4                     SCHOOL, PUBLIC, BUILDING   False     False
#
#                ...                Ward  Community Area  FBI Code  \
# 0              ...                41.0            10.0        06
# 1              ...                 6.0            44.0         6
# 2              ...                41.0            76.0         6
# 3              ...                21.0            71.0         6
# 4              ...                40.0            13.0         6
#
#    X Coordinate Y Coordinate    Year          Updated On   Latitude  \
# 0     1129230.0    1933315.0  2015.0 2015-07-12 12:42:46  41.973309
# 1     1181279.0    1852568.0  2016.0 2016-02-04 15:44:00  41.750687
# 2           NaN          NaN  2016.0 2016-02-02 15:58:00        NaN
# 3     1166776.0    1850053.0  2016.0 2016-05-12 15:48:00  41.744107
# 4           NaN          NaN  2016.0 2016-05-25 15:59:00        NaN
#
#    Longitude                       Location
# 0 -87.800175  (41.973309466, -87.800174996)
# 1 -87.611277   (41.75068679, -87.611276811)
# 2        NaN                           None
# 3 -87.664494  (41.744106973, -87.664494285)
# 4        NaN                           None
#
# [5 rows x 22 columns]

# %% [markdown]
# __Advanced features:__ [Learn more](../../how-to-guides/replace-fill-error.ipynb) about more advanced `replace` and `fill` capabilities.

# %% [markdown]
# ### Données résultats

# %%
theft_replaced.to_pandas_dataframe()
# Out:
#            ID Case Number                        Date                   Block  \
# 0  10140490.0    HY329907      07/05/2015 11:50:00 PM     050XX N NEWLAND AVE
# 1  10374720.0    HZ110836              1/10/2016 7:30      079XX S RHODES AVE
# 2  10400131.0    HZ136171             1/10/2016 18:00     0000X W TERMINAL ST
# 3  10516598.0    HZ258664  2016-04-15T17:00:00.000000  082XX S MARSHFIELD AVE
# 4  10534446.0    HZ277630  2016-04-15T10:00:00.000000      055XX N KEDZIE AVE
# 5  10535059.0    HZ278872  2016-04-15T04:30:00.000000    004XX S KILBOURN AVE
#
#     IUCR Primary Type     Description  \
# 0  820.0        THEFT  $500 AND UNDER
# 1  890.0        THEFT   FROM BUILDING
# 2  810.0        THEFT       OVER $500
# 3  890.0        THEFT   FROM BUILDING
# 4  890.0        THEFT   FROM BUILDING
# 5  810.0        THEFT       OVER $500
#
#                           Location Description  Arrest  Domestic  \
# 0                                       STREET   False     False
# 1                                        OTHER   False     False
# 2  AIRPORT BUILDING NON-TERMINAL - SECURE AREA   False     False
# 3                                    RESIDENCE   False     False
# 4                     SCHOOL, PUBLIC, BUILDING   False     False
# 5                                    RESIDENCE   False     False
#
#                ...                Ward  Community Area  FBI Code  \
# 0              ...                41.0            10.0        06
# 1              ...                 6.0            44.0         6
# 2              ...                41.0            76.0         6
# 3              ...                21.0            71.0         6
# 4              ...                40.0            13.0         6
# 5              ...                24.0            26.0         6
#
#    X Coordinate Y Coordinate    Year          Updated On   Latitude  \
# 0     1129230.0    1933315.0  2015.0 2015-07-12 12:42:46  41.973309
# 1     1181279.0    1852568.0  2016.0 2016-02-04 15:44:00  41.750687
# 2           NaN          NaN  2016.0 2016-02-02 15:58:00        NaN
# 3     1166776.0    1850053.0  2016.0 2016-05-12 15:48:00  41.744107
# 4           NaN          NaN  2016.0 2016-05-25 15:59:00        NaN
# 5           NaN          NaN  2016.0 2016-05-25 15:59:00        NaN
#
#    Longitude                       Location
# 0 -87.800175  (41.973309466, -87.800174996)
# 1 -87.611277   (41.75068679, -87.611276811)
# 2        NaN                           None
# 3 -87.664494  (41.744106973, -87.664494285)
# 4        NaN                           None
# 5        NaN                           None
#
# [6 rows x 22 columns]

# %% [markdown]
# <a id="Explore"></a>

# %% [markdown]
# ## 9. Autres fonctions de Préparation de données avec Azure ML service
#
# Congratulations on finishing your introduction to the Azure ML Data Prep SDK! If you'd like more detailed tutorials on how to construct machine learning datasets or dive deeper into all of its functionality, you can find more information in our detailed notebooks [here](https://github.com/Microsoft/PendletonDocs). There, we cover topics including how to:
#
# * [Cache your Dataflow to speed up your iterations](../../how-to-guides/cache.ipynb)
# * [Add your custom Python transforms](../../how-to-guides/custom-python-transforms.ipynb)
# * [Impute missing values](../../how-to-guides/impute-missing-values.ipynb)
# * [Sample your data](../../how-to-guides/subsetting-sampling.ipynb)
# * [Reference and link between Dataflows](../../how-to-guides/join.ipynb)

# %% [markdown]
# > Fin
